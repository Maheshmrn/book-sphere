# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheshmrn/book-sphere/blob/main/booksphere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
rating = pd.read_csv('/content/drive/MyDrive/Ratings.csv.zip')
rating.head()
rating.shape
rating.isnull().sum()
rating.duplicated().sum()
# Out:
# np.int64(0)

# %%
books = pd.read_csv("/content/drive/MyDrive/Books.csv.zip")
books.head()
books.shape
books.isnull().sum()
books.duplicated().sum()
# Out:
# <ipython-input-3-be7bac6fd83e>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("/content/drive/MyDrive/Books.csv.zip")
# np.int64(0)

# %%
rating_with_name = rating.merge(books,on = 'ISBN')
num_rating = rating_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating.rename(columns={'Book-Rating' : 'num-rating'}, inplace = True)
num_rating
# Out:
#                                                Book-Title  num-rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
avg_rating = rating_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating.rename(columns={'Book-Rating' : 'avg-rating'},inplace = True)
avg_rating
# Out:
#                                                Book-Title  avg-rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_books = num_rating.merge(avg_rating, on = 'Book-Title')
popular_books
# Out:
#                                                Book-Title  num-rating  \
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
#         avg-rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# 4         0.000000
# ...

# %%
popular_books = popular_books[popular_books['num-rating']>=250].sort_values('avg-rating',ascending= False).head(50)
popular_books
# Out:
#                                                Book-Title  num-rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 80422        Harry Potter and the Goblet of Fire (Book 4)         387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)         278
# 80426   Harry Potter and the Order of the Phoenix (Boo...         347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)         556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...         281
# 187377  The Fellowship of the Ring (The Lord of the Ri...         368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 211384     The Two Towers (The Lord of the Rings, Part 2)         260
# 219741                              To Kill a Mockingbird         510
# 183573                                  The Da Vinci Code         898
# 187880                 The Five People You Meet in Heaven         430
# ...

# %%
popular_books = popular_books[['Book-Title','Book-Author','Image-URL-M','num-rating','avg-rating']].fillna(0)
popular_books
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %%
x = rating_with_name.groupby('User-ID').count()['Book-Rating'] >= 200
most_rating_users = x[x].index
most_rating_users
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,   6323,
#          6543,
#        ...
#        271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=816)

# %%
filtered_rating = rating_with_name[rating_with_name['User-ID'].isin(most_rating_users)]
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating'] >= 50
famous_books = y[y].index
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=707)

# %%
final_rating = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
final_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# ...

# %%
pt = final_rating.pivot_table(index = 'Book-Title',columns= 'User-ID',values = 'Book-Rating')
pt.fillna(0,inplace = True)
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
#execution code
from sklearn.metrics.pairwise import cosine_similarity
similar_scores = cosine_similarity(pt)
similar_scores.shape
# Out:
# (707, 707)

# %%
#popularity based function
def popular_books_list():
    results = []
    for title in popular_books['Book-Title']:
        books1 = books[books['Book-Title'] == title].drop_duplicates('Book-Title').merge(popular_books[['Book-Title', 'avg-rating']], on='Book-Title', how='left')
        book_info = []
        book_info.extend(list(books1['Book-Title'].values))
        book_info.extend(list(books1['Book-Author'].values))
        book_info.extend(list(books1['Image-URL-M'].values))
        book_info.extend(list(books1['avg-rating'].values))
        print(book_info)

# %%
#collaborative based function
def bookSphere(book_name):
  index = np.where(pt.index == book_name)[0][0]
  similar_books = sorted(list(enumerate(similar_scores[index])),key = lambda x:x[1],reverse = True)[1:10]
  for i in similar_books :
    book_info = []
    books1 = books[books['Book-Title'] == pt.index[i[0]]].merge(popular_books[['Book-Title', 'avg-rating']], on='Book-Title', how='left')
    book_info.extend(list(books1.drop_duplicates('Book-Title')['Book-Title'].values))
    book_info.extend(list(books1.drop_duplicates('Book-Title')['Book-Author'].values))
    book_info.extend(list(books1.drop_duplicates('Book-Title')['Image-URL-M'].values))
    book_info.extend(list(books1.drop_duplicates('Book-Title')['avg-rating'].values))
    print(book_info)

# %%
popular_books_list()
# Out:
# ['Harry Potter and the Prisoner of Azkaban (Book 3)', 'J. K. Rowling', 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg', np.float64(5.852803738317757)]
# ['Harry Potter and the Goblet of Fire (Book 4)', 'J. K. Rowling', 'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg', np.float64(5.8242894056847545)]
# ["Harry Potter and the Sorcerer's Stone (Book 1)", 'J. K. Rowling', 'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg', np.float64(5.737410071942446)]
# ['Harry Potter and the Order of the Phoenix (Book 5)', 'J. K. Rowling', 'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg', np.float64(5.501440922190202)]
# ['Harry Potter and the Chamber of Secrets (Book 2)', 'J. K. Rowling', 'http://images.amazon.com/images/P/0439064872.01.MZZZZZZZ.jpg', np.float64(5.183453237410072)]
# ...

# %%
bookSphere('1984')
# Out:
# ['Animal Farm', 'George Orwell', 'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg', np.float64(nan)]
# ["The Handmaid's Tale", 'Margaret Atwood', 'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg', np.float64(nan)]
# ['Brave New World', 'Aldous Huxley', 'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg', np.float64(nan)]
# ['The Vampire Lestat (Vampire Chronicles, Book II)', 'ANNE RICE', 'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg', np.float64(3.777408637873754)]
# ['The Hours : A Novel', 'Michael Cunningham', 'http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg', np.float64(nan)]
# ['Fahrenheit 451', 'Ray Bradbury', 'http://images.amazon.com/images/P/3257208626.01.MZZZZZZZ.jpg', np.float64(4.264058679706602)]
# ['The Catcher in the Rye', 'J.D. Salinger', 'http://images.amazon.com/images/P/0316769487.01.MZZZZZZZ.jpg', np.float64(4.5456570155902005)]
# ...

# %%
bookSphere('A Walk to Remember')
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
bookSphere('The Da Vinci Code')
# Out:
# ['Angels &amp; Demons', 'Dan Brown', 'http://images.amazon.com/images/P/0671027360.01.MZZZZZZZ.jpg', np.float64(nan)]
# ['Touching Evil', 'Kay Hooper', 'http://images.amazon.com/images/P/0553583441.01.MZZZZZZZ.jpg', np.float64(nan)]
# ['Saving Faith', 'David Baldacci', 'http://images.amazon.com/images/P/0446608890.01.MZZZZZZZ.jpg', np.float64(nan)]
# ["The Sweet Potato Queens' Book of Love", 'JILL CONNER BROWNE', 'http://images.amazon.com/images/P/0609804138.01.MZZZZZZZ.jpg', np.float64(nan)]
# ['Middlesex: A Novel', 'Jeffrey Eugenides', 'http://images.amazon.com/images/P/0312422156.01.MZZZZZZZ.jpg', np.float64(nan)]
# ['The Blue Nowhere : A Novel', 'Jeffery Deaver', 'http://images.amazon.com/images/P/0671042262.01.MZZZZZZZ.jpg', np.float64(nan)]
# ['The Lovely Bones: A Novel', 'Alice Sebold', 'http://images.amazon.com/images/P/0316666343.01.MZZZZZZZ.jpg', np.float64(4.468725868725869)]
# ...

# %%
pt.index[200]
# Out:
# "Fortune's Rocks : A Novel"
